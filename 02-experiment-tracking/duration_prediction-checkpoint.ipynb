# %%
import os
print("Notebook path:", os.getcwd())
# Out:
# Notebook path: /workspaces/MLOps_zoomcamp/02-experiment-tracking

# %%
# !python -V
# Out:
# Python 3.9.21

# %%
import pandas as pd
import numpy as np
import pickle
import seaborn as sns
import matplotlib as plt

# %%
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge

from sklearn.metrics import mean_squared_error

# %%
import mlflow


mlflow.set_tracking_uri("sqlite:///mlflow.db")
mlflow.set_experiment("nyc-taxi-experiment")
# Out:
# <Experiment: artifact_location='/workspaces/MLOps_zoomcamp/02-experiment-tracking/mlruns/1', creation_time=1747908577392, experiment_id='1', last_update_time=1747908577392, lifecycle_stage='active', name='nyc-taxi-experiment', tags={}>

# %%
with mlflow.start_run():
    mlflow.log_param("alpha", 0.1)
    mlflow.log_metric("rmse", 5.67)

print("✅ Run logged")
# Out:
# ✅ Run logged

# %%
def read_dataframe(filename):
    df = pd.read_parquet(filename)

    df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)
    df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)

    df['duration'] = df.lpep_dropoff_datetime - df.lpep_pickup_datetime
    df.duration = df.duration.apply(lambda td: td.total_seconds() / 60)

    df = df[(df.duration >= 1) & (df.duration <= 60)]

    categorical = ['PULocationID', 'DOLocationID']
    df[categorical] = df[categorical].astype(str)
    
    return df

# %%
df_train = read_dataframe('./data/green_tripdata_2021-01.parquet')
df_val = read_dataframe('./data/green_tripdata_2021-02.parquet')

# %%
len(df_train), len(df_val)
# Out:
# (73908, 61921)

# %%
df_train['PU_DO'] = df_train['PULocationID'] + '_' + df_train['DOLocationID']
df_val['PU_DO'] = df_val['PULocationID'] + '_' + df_val['DOLocationID']

# %%
categorical = ['PU_DO'] #'PULocationID', 'DOLocationID']
numerical = ['trip_distance']

dv = DictVectorizer()

train_dicts = df_train[categorical + numerical].to_dict(orient='records')
X_train = dv.fit_transform(train_dicts)

val_dicts = df_val[categorical + numerical].to_dict(orient='records')
X_val = dv.transform(val_dicts)

# %%
target = 'duration'
y_train = df_train[target].values
y_val = df_val[target].values

# %%
# Train the linear regression model
lr = LinearRegression()
lr.fit(X_train, y_train)

# Predict
y_pred = lr.predict(X_val)

# Calculate RMSE manually
rmse = np.sqrt(mean_squared_error(y_val, y_pred))
print("RMSE:", rmse)
# Out:
# RMSE: 7.758715208009878

# %%
with open('models/lin_reg.bin', 'wb') as f_out:
    pickle.dump((dv, lr), f_out)

# %%
# Train the lasso model
lr = Lasso()
lr.fit(X_train, y_train)

# Predict
y_pred = lr.predict(X_val)

# Calculate RMSE manually
rmse = np.sqrt(mean_squared_error(y_val, y_pred))
print("RMSE:", rmse)
# Out:
# RMSE: 12.212583224318818

# %%
with mlflow.start_run():

    mlflow.set_tag("developer", "cristian")

    mlflow.log_param("train-data-path", "./data/green_tripdata_2021-01.csv")
    mlflow.log_param("valid-data-path", "./data/green_tripdata_2021-02.csv")

    alpha = 0.01
    mlflow.log_param("alpha", alpha)
    lr = Lasso(alpha)
    lr.fit(X_train, y_train)

    y_pred = lr.predict(X_val)
    rmse = np.sqrt(mean_squared_error(y_val, y_pred))
    mlflow.log_metric("rmse", rmse)

    mlflow.log_artifact(local_path="models/lin_reg.bin", artifact_path="models_pickle")

# %% [markdown]
# # Define objective function  xgboost

# %%
import xgboost as xgb
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials 
from hyperopt.pyll import scope

# %%
train = xgb.DMatrix(X_train, label=y_train)
valid = xgb.DMatrix(X_val, label=y_val)

# %%
def objective(params):
    with mlflow.start_run():
        mlflow.set_tag("model", "xgboost")
        mlflow.log_params(params)
        booster = xgb.train(
            params=params,
            dtrain=train,
            num_boost_round=1000,
            evals=[(valid, 'validation')],
            early_stopping_rounds=50
        )
        y_pred = booster.predict(valid)
        rmse = np.sqrt(mean_squared_error(y_val, y_pred))
        mlflow.log_metric("rmse", rmse)

    return {'loss': rmse, 'status': STATUS_OK}

# %%
search_space = {
    'max_depth': scope.int(hp.quniform('max_depth', 4, 100, 1)),
    'learning_rate': hp.loguniform('learning_rate', -3, 0),
    'reg_alpha': hp.loguniform('reg_alpha', -5, -1),
    'reg_lambda': hp.loguniform('reg_lambda', -6, -1),
    'min_child_weight': hp.loguniform('min_child_weight', -1, 3),
    'objective': 'reg:linear',
    'seed': 42
}

#best_result = fmin(
#    fn=objective,
#    space=search_space,
#    algo=tpe.suggest,
#    max_evals=10, # should be 50
#    trials=Trials()
#)

# %%
#import mlflow.xgboost


import mlflow.xgboost


params = {
        'learning_rate': 0.187,
        'max_depth': 47,
        'min_child_weight': 2.354,
        'objective': 'reg:linear',
        'reg_alpha': 0.01275,
        'reg_lambda':0.0461,
        'seed': 42
    }


with mlflow.start_run():

    # ✅ Add a descriptive tag
    mlflow.set_tag("model", "xgboost")

    # ✅ Log parameters
    for key, value in params.items():
        mlflow.log_param(key, value)

    booster = xgb.train(
            params=params,
            dtrain=train,
            num_boost_round=1000,
            evals=[(valid, 'validation')],
            early_stopping_rounds=10
    )

    y_pred = booster.predict(valid)
    rmse = np.sqrt(mean_squared_error(y_val, y_pred))
    mlflow.log_metric("rmse", rmse)
# Out:
# /home/codespace/anaconda3/envs/experiment-tracking/lib/python3.9/site-packages/xgboost/core.py:158: UserWarning: [15:39:37] WARNING: /workspace/src/objective/regression_obj.cu:227: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# [0]	validation-rmse:10.72238
# [1]	validation-rmse:9.59456
# [2]	validation-rmse:8.75302
# [3]	validation-rmse:8.13371
# [4]	validation-rmse:7.68551
# [5]	validation-rmse:7.36269
# [6]	validation-rmse:7.13029
# [7]	validation-rmse:6.96371
# [8]	validation-rmse:6.84388
# [9]	validation-rmse:6.75450
# [10]	validation-rmse:6.69081
# [11]	validation-rmse:6.64319
# [12]	validation-rmse:6.60628
# [13]	validation-rmse:6.57824
# [14]	validation-rmse:6.55542
# [15]	validation-rmse:6.53761
# [16]	validation-rmse:6.52387
# [17]	validation-rmse:6.51339
# [18]	validation-rmse:6.50421
# [19]	validation-rmse:6.49537
# [20]	validation-rmse:6.48862
# [21]	validation-rmse:6.48380
# [22]	validation-rmse:6.47849
# [23]	validation-rmse:6.47274
# [24]	validation-rmse:6.46911
# [25]	validation-rmse:6.46551
# [26]	validation-rmse:6.46379
# [27]	validation-rmse:6.46281
# [28]	validation-rmse:6.46101
# [29]	validation-rmse:6.45883
# [30]	validation-rmse:6.45637
# [31]	validation-rmse:6.45443
# [32]	validation-rmse:6.45303
# [33]	validation-rmse:6.45107
# [34]	validation-rmse:6.44897
# [35]	validation-rmse:6.44753
# [36]	validation-rmse:6.44559
# [37]	validation-rmse:6.44418
# [38]	validation-rmse:6.44236
# [39]	validation-rmse:6.44123
# [40]	validation-rmse:6.43929
# [41]	validation-rmse:6.43762
# [42]	validation-rmse:6.43541
# [43]	validation-rmse:6.43475
# [44]	validation-rmse:6.43353
# [45]	validation-rmse:6.43216
# [46]	validation-rmse:6.43094
# [47]	validation-rmse:6.43003
# [48]	validation-rmse:6.42896
# [49]	validation-rmse:6.42762
# [50]	validation-rmse:6.42649
# [51]	validation-rmse:6.42539
# [52]	validation-rmse:6.42405
# [53]	validation-rmse:6.42324
# [54]	validation-rmse:6.42193
# [55]	validation-rmse:6.42076
# [56]	validation-rmse:6.41965
# [57]	validation-rmse:6.41845
# [58]	validation-rmse:6.41798
# [59]	validation-rmse:6.41725
# [60]	validation-rmse:6.41650
# [61]	validation-rmse:6.41525
# [62]	validation-rmse:6.41428
# [63]	validation-rmse:6.41283
# [64]	validation-rmse:6.41214
# [65]	validation-rmse:6.41066
# [66]	validation-rmse:6.40968
# [67]	validation-rmse:6.40900
# [68]	validation-rmse:6.40827
# [69]	validation-rmse:6.40792
# [70]	validation-rmse:6.40743
# [71]	validation-rmse:6.40642
# [72]	validation-rmse:6.40530
# [73]	validation-rmse:6.40477
# [74]	validation-rmse:6.40418
# [75]	validation-rmse:6.40336
# [76]	validation-rmse:6.40242
# [77]	validation-rmse:6.40175
# [78]	validation-rmse:6.40077
# [79]	validation-rmse:6.39974
# [80]	validation-rmse:6.39888
# [81]	validation-rmse:6.39764
# [82]	validation-rmse:6.39729
# [83]	validation-rmse:6.39677
# [84]	validation-rmse:6.39616
# [85]	validation-rmse:6.39548
# [86]	validation-rmse:6.39456
# [87]	validation-rmse:6.39400
# [88]	validation-rmse:6.39333
# [89]	validation-rmse:6.39283
# [90]	validation-rmse:6.39238
# [91]	validation-rmse:6.39205
# [92]	validation-rmse:6.39152
# [93]	validation-rmse:6.39071
# [94]	validation-rmse:6.39043
# [95]	validation-rmse:6.38954
# [96]	validation-rmse:6.38909
# [97]	validation-rmse:6.38869
# [98]	validation-rmse:6.38759
# [99]	validation-rmse:6.38727
# [100]	validation-rmse:6.38656
# [101]	validation-rmse:6.38615
# [102]	validation-rmse:6.38532
# [103]	validation-rmse:6.38516
# [104]	validation-rmse:6.38471
# [105]	validation-rmse:6.38426
# [106]	validation-rmse:6.38427
# [107]	validation-rmse:6.38353
# [108]	validation-rmse:6.38331
# [109]	validation-rmse:6.38323
# [110]	validation-rmse:6.38237
# [111]	validation-rmse:6.38136
# [112]	validation-rmse:6.38067
# [113]	validation-rmse:6.38048
# [114]	validation-rmse:6.38004
# [115]	validation-rmse:6.37964
# [116]	validation-rmse:6.37878
# [117]	validation-rmse:6.37814
# [118]	validation-rmse:6.37777
# [119]	validation-rmse:6.37742
# [120]	validation-rmse:6.37670
# [121]	validation-rmse:6.37645
# [122]	validation-rmse:6.37600
# [123]	validation-rmse:6.37554
# [124]	validation-rmse:6.37507
# [125]	validation-rmse:6.37454
# [126]	validation-rmse:6.37417
# [127]	validation-rmse:6.37384
# [128]	validation-rmse:6.37373
# [129]	validation-rmse:6.37352
# [130]	validation-rmse:6.37315
# [131]	validation-rmse:6.37240
# [132]	validation-rmse:6.37220
# [133]	validation-rmse:6.37197
# [134]	validation-rmse:6.37163
# [135]	validation-rmse:6.36989
# [136]	validation-rmse:6.36976
# [137]	validation-rmse:6.36953
# [138]	validation-rmse:6.36912
# [139]	validation-rmse:6.36901
# [140]	validation-rmse:6.36886
# [141]	validation-rmse:6.36820
# [142]	validation-rmse:6.36723
# [143]	validation-rmse:6.36706
# [144]	validation-rmse:6.36648
# [145]	validation-rmse:6.36611
# [146]	validation-rmse:6.36547
# [147]	validation-rmse:6.36492
# [148]	validation-rmse:6.36493
# [149]	validation-rmse:6.36482
# [150]	validation-rmse:6.36461
# [151]	validation-rmse:6.36408
# [152]	validation-rmse:6.36384
# [153]	validation-rmse:6.36335
# [154]	validation-rmse:6.36254
# [155]	validation-rmse:6.36237
# [156]	validation-rmse:6.36205
# [157]	validation-rmse:6.36202
# [158]	validation-rmse:6.36214
# [159]	validation-rmse:6.36176
# [160]	validation-rmse:6.36132
# [161]	validation-rmse:6.36129
# [162]	validation-rmse:6.36110
# [163]	validation-rmse:6.36086
# [164]	validation-rmse:6.36078
# [165]	validation-rmse:6.36045
# [166]	validation-rmse:6.36006
# [167]	validation-rmse:6.35969
# [168]	validation-rmse:6.35941
# [169]	validation-rmse:6.35913
# [170]	validation-rmse:6.35894
# [171]	validation-rmse:6.35844
# [172]	validation-rmse:6.35854
# [173]	validation-rmse:6.35789
# [174]	validation-rmse:6.35775
# [175]	validation-rmse:6.35755
# [176]	validation-rmse:6.35729
# [177]	validation-rmse:6.35716
# [178]	validation-rmse:6.35671
# [179]	validation-rmse:6.35663
# [180]	validation-rmse:6.35634
# [181]	validation-rmse:6.35631
# [182]	validation-rmse:6.35610
# [183]	validation-rmse:6.35614
# [184]	validation-rmse:6.35596
# [185]	validation-rmse:6.35606
# [186]	validation-rmse:6.35584
# [187]	validation-rmse:6.35544
# [188]	validation-rmse:6.35526
# [189]	validation-rmse:6.35484
# [190]	validation-rmse:6.35476
# [191]	validation-rmse:6.35383
# [192]	validation-rmse:6.35367
# [193]	validation-rmse:6.35344
# [194]	validation-rmse:6.35329
# [195]	validation-rmse:6.35326
# [196]	validation-rmse:6.35296
# [197]	validation-rmse:6.35276
# [198]	validation-rmse:6.35265
# [199]	validation-rmse:6.35235
# [200]	validation-rmse:6.35167
# [201]	validation-rmse:6.35171
# [202]	validation-rmse:6.35139
# [203]	validation-rmse:6.35188
# [204]	validation-rmse:6.35163
# [205]	validation-rmse:6.35138
# [206]	validation-rmse:6.35134
# [207]	validation-rmse:6.35108
# [208]	validation-rmse:6.35105
# [209]	validation-rmse:6.35095
# [210]	validation-rmse:6.35079
# [211]	validation-rmse:6.35040
# [212]	validation-rmse:6.35031
# [213]	validation-rmse:6.34989
# [214]	validation-rmse:6.34958
# [215]	validation-rmse:6.34922
# [216]	validation-rmse:6.34900
# [217]	validation-rmse:6.34846
# [218]	validation-rmse:6.34835
# [219]	validation-rmse:6.34817
# [220]	validation-rmse:6.34800
# [221]	validation-rmse:6.34794
# [222]	validation-rmse:6.34781
# [223]	validation-rmse:6.34773
# [224]	validation-rmse:6.34765
# [225]	validation-rmse:6.34767
# [226]	validation-rmse:6.34727
# [227]	validation-rmse:6.34728
# [228]	validation-rmse:6.34708
# [229]	validation-rmse:6.34691
# [230]	validation-rmse:6.34686
# [231]	validation-rmse:6.34715
# [232]	validation-rmse:6.34704
# [233]	validation-rmse:6.34674
# [234]	validation-rmse:6.34659
# [235]	validation-rmse:6.34606
# [236]	validation-rmse:6.34581
# [237]	validation-rmse:6.34564
# [238]	validation-rmse:6.34547
# [239]	validation-rmse:6.34558
# [240]	validation-rmse:6.34512
# [241]	validation-rmse:6.34524
# [242]	validation-rmse:6.34519
# [243]	validation-rmse:6.34526
# [244]	validation-rmse:6.34529
# [245]	validation-rmse:6.34515
# [246]	validation-rmse:6.34523
# [247]	validation-rmse:6.34458
# [248]	validation-rmse:6.34469
# [249]	validation-rmse:6.34463
# [250]	validation-rmse:6.34461
# [251]	validation-rmse:6.34394
# [252]	validation-rmse:6.34390
# [253]	validation-rmse:6.34417
# [254]	validation-rmse:6.34397
# [255]	validation-rmse:6.34404
# [256]	validation-rmse:6.34359
# [257]	validation-rmse:6.34290
# [258]	validation-rmse:6.34283
# [259]	validation-rmse:6.34273
# [260]	validation-rmse:6.34250
# [261]	validation-rmse:6.34242
# [262]	validation-rmse:6.34228
# [263]	validation-rmse:6.34227
# [264]	validation-rmse:6.34215
# [265]	validation-rmse:6.34137
# [266]	validation-rmse:6.34144
# [267]	validation-rmse:6.34153
# [268]	validation-rmse:6.34135
# [269]	validation-rmse:6.34142
# [270]	validation-rmse:6.34101
# [271]	validation-rmse:6.34115
# [272]	validation-rmse:6.34114
# [273]	validation-rmse:6.34095
# [274]	validation-rmse:6.34082
# [275]	validation-rmse:6.34055
# [276]	validation-rmse:6.34023
# [277]	validation-rmse:6.34012
# [278]	validation-rmse:6.33963
# [279]	validation-rmse:6.33918
# [280]	validation-rmse:6.33902
# [281]	validation-rmse:6.33887
# [282]	validation-rmse:6.33870
# [283]	validation-rmse:6.33832
# [284]	validation-rmse:6.33790
# [285]	validation-rmse:6.33805
# [286]	validation-rmse:6.33809
# [287]	validation-rmse:6.33803
# [288]	validation-rmse:6.33799
# [289]	validation-rmse:6.33784
# [290]	validation-rmse:6.33801
# [291]	validation-rmse:6.33772
# [292]	validation-rmse:6.33753
# [293]	validation-rmse:6.33747
# [294]	validation-rmse:6.33757
# [295]	validation-rmse:6.33717
# [296]	validation-rmse:6.33730
# [297]	validation-rmse:6.33753
# [298]	validation-rmse:6.33740
# [299]	validation-rmse:6.33731
# [300]	validation-rmse:6.33723
# [301]	validation-rmse:6.33748
# [302]	validation-rmse:6.33692
# [303]	validation-rmse:6.33689
# [304]	validation-rmse:6.33674
# [305]	validation-rmse:6.33668
# [306]	validation-rmse:6.33658
# [307]	validation-rmse:6.33663
# [308]	validation-rmse:6.33674
# [309]	validation-rmse:6.33664
# [310]	validation-rmse:6.33657
# [311]	validation-rmse:6.33628
# [312]	validation-rmse:6.33632
# [313]	validation-rmse:6.33617
# [314]	validation-rmse:6.33604
# [315]	validation-rmse:6.33606
# [316]	validation-rmse:6.33626
# [317]	validation-rmse:6.33632
# [318]	validation-rmse:6.33606
# [319]	validation-rmse:6.33601
# [320]	validation-rmse:6.33598
# [321]	validation-rmse:6.33597
# [322]	validation-rmse:6.33593
# [323]	validation-rmse:6.33590
# [324]	validation-rmse:6.33579
# [325]	validation-rmse:6.33577
# [326]	validation-rmse:6.33578
# [327]	validation-rmse:6.33549
# [328]	validation-rmse:6.33556
# [329]	validation-rmse:6.33493
# [330]	validation-rmse:6.33493
# [331]	validation-rmse:6.33498
# [332]	validation-rmse:6.33491
# [333]	validation-rmse:6.33499
# [334]	validation-rmse:6.33493
# [335]	validation-rmse:6.33500
# [336]	validation-rmse:6.33501
# [337]	validation-rmse:6.33496
# [338]	validation-rmse:6.33496
# [339]	validation-rmse:6.33512
# [340]	validation-rmse:6.33508
# [341]	validation-rmse:6.33506
